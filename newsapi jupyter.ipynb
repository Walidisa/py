# %%
from newsapi import NewsApiClient
import pandas as pd
# Init
'''all_articles = newsapi.get_everything(q='bitcoin',
                                      sources='bbc-news,the-verge',
                                      domains='bbc.co.uk,techcrunch.com',
                                      from_param='2017-12-01',
                                      to='2017-12-12',
                                      language='en',
                                      sort_by='relevancy',
                                      page=2)'''
newsapi = NewsApiClient(api_key='d7e0d34a808c4b319e68046097287a52')
topic = input("What would you like to know about?: ")
date1 = input("From whcih date should the news be about?format is YYYY-MM-DD: ")
date2 = input("To which date should the news be? format is YYYY-MM-DD: ")
headlines = newsapi.get_everything(q=topic, from_param=date1, to=date2, language='en', sort_by='relevancy')
articles = headlines['articles']

# %%
print("HERE ARE THE HEADLINES!!")
for x,y in enumerate(articles):
    print(f'{x} {y['title']}')
num = int(input("Which headline whould you like to know more about?: ")) 
#articles = articles - articles['url']   
table = pd.DataFrame(articles[num])
#content = table['content']
#print(articles[num]['content'])
# Out:
# HERE ARE THE HEADLINES!!
# 0 Everything to Know About Bitcoin Pizza Day
# 1 Craig Wright Lied About Creating Bitcoin And Faked Evidence, Judge Rules
# 2 Bitcoin Indicator Flashes “Buy” Signal as BTC Price Remains Flat – Next Crypto to Explode?
# 3 Self-Proclaimed Bitcoin Inventor Lied 'Repeatedly' To Support Claim, Says UK Judge
# 4 SEC approves Ethereum ETF on Nasdaq, NYSE, CBOE
# 5 Former Chinese takeaway worker jailed for money laundering after police seized 61,000 bitcoins — currently worth $4 billion
# 6 Why Donald Trump Is Betting on Crypto
# 7 Dutch cybercops tracked a crypto theft to one of the world’s worst botnets
# 8 Stock market today: Indexes pop after Nvidia's blowout earnings report
# 9 Bitcoin Is Coming to Ethereum Stalwart MetaMask: Sources
# 10 Controversial crypto bill FIT21 passes House
# 11 Walls are starting to close in for Tesla, let's have a closer look
# 12 The Sea Change on Crypto-Regulation
# ...
